# %%
import plot_fig1_v2
plot_fig1_v2.plot_all(save=True)
# Out:
# findfont: Font family ['cursive'] not found. Falling back to DejaVu Sans.
# findfont: Generic family 'cursive' not found because none of the following families were found: Apple Chancery, Textile, Zapf Chancery, Sand, Script MT, Felipa, Comic Neue, Comic Sans MS, cursive
# data.max() > vmax, the plotting result can be misleading
# data.max() > vmax, the plotting result can be misleading
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# ...

# %%
import plot_fig2_v3
plot_fig2_v3.plot_all(save=True)
# Out:
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# data.max() > vmax, the plotting result can be misleading
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# ...

# %%
import plot_fig2_nonintegrable_T_5
plot_fig2_nonintegrable_T_5.plot_all(save=True)
# Out:
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# data.max() > vmax, the plotting result can be misleading
# data.max() > vmax, the plotting result can be misleading
# Saved  figures/fig2.pdf

# %%
import plot_fig3_v4
plot_fig3_v4.plot_all(save=True)
# Out:
# data.max() > vmax, the plotting result can be misleading
# data.max() > vmax, the plotting result can be misleading
# data.max() > vmax, the plotting result can be misleading
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# Saved  figures/fig3_v4.pdf
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# ...

# %%
import plot_fig3_v5
plot_fig3_v5.plot_all(save=True)
# Out:
# data.max() > vmax, the plotting result can be misleading
# data.max() > vmax, the plotting result can be misleading
# data.max() > vmax, the plotting result can be misleading
# /home/kristian/Documents/eddqc/analysis/plotting/plot_fig3_v5.py:560: SyntaxWarning: invalid escape sequence '\p'
#   labels=["$-\pi$", 0, "$\pi$"],
# /home/kristian/Documents/eddqc/analysis/plotting/plot_fig3_v5.py:560: SyntaxWarning: invalid escape sequence '\p'
#   labels=["$-\pi$", 0, "$\pi$"],
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 2
#       1 import plot_fig3_v5
# ----> 2 plot_fig3_v5.plot_all(save=True)
#
# File ~/Documents/eddqc/analysis/plotting/styles.py:47, in article_style.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#      45     actual_rcparams[actual_key] = rcparams[key]
#      46 mpl.rcParams.update(actual_rcparams)
# ...

# %%
import plot_fig3_v6
plot_fig3_v6.plot_all(save=True)
# Out:
# findfont: Font family ['cursive'] not found. Falling back to DejaVu Sans.
# findfont: Generic family 'cursive' not found because none of the following families were found: Apple Chancery, Textile, Zapf Chancery, Sand, Script MT, Felipa, Comic Neue, Comic Sans MS, cursive
# data.max() > vmax, the plotting result can be misleading
# data.max() > vmax, the plotting result can be misleading
# data.max() > vmax, the plotting result can be misleading
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# ...

# %%
import plot_fig3_v7
plot_fig3_v7.plot_all(save=True)
# Out:
# data.max() > vmax, the plotting result can be misleading
# data.max() > vmax, the plotting result can be misleading
# data.max() > vmax, the plotting result can be misleading
# /home/kristian/Documents/eddqc/analysis/plotting/plot_fig3_v7.py:560: SyntaxWarning: invalid escape sequence '\p'
#   labels=["$-\pi$", 0, "$\pi$"],
# /home/kristian/Documents/eddqc/analysis/plotting/plot_fig3_v7.py:560: SyntaxWarning: invalid escape sequence '\p'
#   labels=["$-\pi$", 0, "$\pi$"],
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 2
#       1 import plot_fig3_v7
# ----> 2 plot_fig3_v7.plot_all(save=True)
#
# File ~/Documents/eddqc/analysis/plotting/styles.py:47, in article_style.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#      45     actual_rcparams[actual_key] = rcparams[key]
#      46 mpl.rcParams.update(actual_rcparams)
# ...
