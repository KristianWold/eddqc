# %% [markdown]
# # Scatterplot, Bootstrap

# %%
import sys
sys.path.insert(0, '../../src/')

import numpy as np
import pickle as pkl
import tensorflow as tf

from tqdm.notebook import tqdm

from analysis import scatterplot_bootstrap, model_to_csr

#np.set_printoptions(threshold=sys.maxsize)
np.set_printoptions(precision=4)

import os
os.environ["CUDA_VISIBLE_DEVICES"] = "-1"
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)
# Out:
# 2025-10-29 00:39:54.643901: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# ## Retrieve CSR
#
# ### L = 5

# %%
seed = 42

r_std_list = []
a_std_list = []

# %%
r_std_list_temp = []
a_std_list_temp = []

for i in tqdm(range(10)):
    models = pkl.load(open(f'../fitting_maps_bootstrap/models/integrable_model_L=5_bootstrap_seed{seed + i}.model', 'rb'))
    csr = model_to_csr(models)
    _, r_std, _, a_std = scatterplot_bootstrap(csr)
    r_std_list_temp.append(r_std)
    a_std_list_temp.append(a_std)


r_std_list_temp = np.array(r_std_list_temp)
a_std_list_temp = np.array(a_std_list_temp)

r_std = np.sqrt(np.mean(r_std_list_temp**2))/np.sqrt(10)
r_std_list.append(r_std)

a_std = np.sqrt(np.mean(a_std_list_temp**2))/np.sqrt(10)
a_std_list.append(a_std)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# 2025-10-29 00:39:56.986167: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2025-10-29 00:39:56.986210: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:160] env: CUDA_VISIBLE_DEVICES="-1"
# 2025-10-29 00:39:56.986218: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:163] CUDA_VISIBLE_DEVICES is set to -1 - this hides all GPUs from CUDA
# 2025-10-29 00:39:56.986225: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:171] verbose logging is disabled. Rerun with verbose logging (usually --v=1 or --vmodule=cuda_diagnostics=1) to get more diagnostic output from this module
# 2025-10-29 00:39:56.986232: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:176] retrieving CUDA diagnostic information for host: BrigidBrain
# 2025-10-29 00:39:56.986236: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:183] hostname: BrigidBrain
# 2025-10-29 00:39:56.986347: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:190] libcuda reported version is: 535.274.2
# 2025-10-29 00:39:56.986377: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:194] kernel reported version is: 535.274.2
# 2025-10-29 00:39:56.986381: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:284] kernel version seems to match DSO: 535.274.2
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_933935/1964290610.py in ?()
#       2 a_std_list_temp = []
#       3
#       4 for i in tqdm(range(10)):
#       5     models = pkl.load(open(f'../fitting_maps_bootstrap/models/integrable_model_L=5_bootstrap_seed{seed + i}.model', 'rb'))
# ----> 6     csr = model_to_csr(models)
#       7     _, r_std, _, a_std = scatterplot_bootstrap(csr)
#       8     r_std_list_temp.append(r_std)
#       9     a_std_list_temp.append(a_std)
#
# ~/Documents/eddqc/analysis/integrable_transition/../../src/analysis.py in ?(model_list)
#     126     spectrum_list = []
#     127     csr_integrable_list = []
#     128     for model in model_list:
#     129         channel = model.channel
# --> 130         spectrum = channel_spectrum(channel)
#     131
#     132         csr = complex_spacing_ratio(spectrum)
#     133
#
# ~/Documents/eddqc/analysis/integrable_transition/../../src/spectrum.py in ?(channel, is_complex, keep_real, keep_unity, tol)
#     114 def channel_spectrum(
#     115     channel, is_complex=False, keep_real=True, keep_unity=True, tol=1e-4
#     116 ):
# --> 117     so = channel.superoperator
#     118
#     119     eig, _ = tf.linalg.eig(so)
#     120     eig = tf.expand_dims(eig, axis=1)
#
# ~/Documents/eddqc/analysis/integrable_transition/../../src/kraus_channels.py in ?(self)
#     137     @property
#     138     def superoperator(self):
# --> 139         return kraus_to_superoperator(self)
#
# ~/Documents/eddqc/analysis/integrable_transition/../../src/quantum_channel.py in ?(kraus_channel)
#      22     so = 0
#      23
#      24     for i in range(rank):
#      25         K = kraus[:, i]
# ---> 26         so += tf_kron(K, tf.math.conj(K))
#      27
#      28     so = so[0]
#      29
#
# ~/anaconda3/envs/env_quantum/lib/python3.13/site-packages/tensorflow/python/util/traceback_utils.py in ?(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#     153       raise e.with_traceback(filtered_tb) from None
#     154     finally:
# --> 155       del filtered_tb
#
# ~/anaconda3/envs/env_quantum/lib/python3.13/site-packages/tensorflow/python/framework/override_binary_operator.py in ?(x, y)
#     110         # TODO(b/178860388): Figure out why binary_op_wrapper and
#     111         #   r_binary_op_wrapper use different force_same_dtype values.
#     112         x, y = maybe_promote_tensors(x, y)
#     113         return func(x, y, name=name)
# --> 114       except (TypeError, ValueError) as e:
#     115         # Even if dispatching the op failed, the RHS may be a tensor aware
#     116         # object that can implement the operator with knowledge of itself
#     117         # and the tensor.
#
# ~/anaconda3/envs/env_quantum/lib/python3.13/site-packages/tensorflow/python/ops/tensor_math_operator_overrides.py in ?(x, y, name)
#      25 def _add_dispatch_factory(x, y, name=None):
#      26   from tensorflow.python.ops import math_ops
#      27
# ---> 28   return math_ops._add_dispatch(x, y, name=name)  # pylint: disable=protected-access
#
# ~/anaconda3/envs/env_quantum/lib/python3.13/site-packages/tensorflow/python/util/traceback_utils.py in ?(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#     153       raise e.with_traceback(filtered_tb) from None
#     154     finally:
# --> 155       del filtered_tb
#
# ~/anaconda3/envs/env_quantum/lib/python3.13/site-packages/tensorflow/python/util/dispatch.py in ?(*args, **kwargs)
#    1261
#    1262       # Fallback dispatch system (dispatch v1):
#    1263       try:
#    1264         return dispatch_target(*args, **kwargs)
# -> 1265       except (TypeError, ValueError):
#    1266         # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1267         # TypeError, when given unexpected types.  So we need to catch both.
#    1268         result = dispatch(op_dispatch_handler, args, kwargs)
#
# ~/anaconda3/envs/env_quantum/lib/python3.13/site-packages/tensorflow/python/ops/math_ops.py in ?(x, y, name)
#    1735     y = ops.convert_to_tensor(y, dtype_hint=x.dtype.base_dtype, name="y")
#    1736   if x.dtype == dtypes.string:
#    1737     return gen_math_ops.add(x, y, name=name)
#    1738   else:
# -> 1739     return gen_math_ops.add_v2(x, y, name=name)
#
# ~/anaconda3/envs/env_quantum/lib/python3.13/site-packages/tensorflow/python/ops/gen_math_ops.py in ?(x, y, name)
#     478         _ctx, "AddV2", name, x, y)
#     479       return _result
#     480     except _core._NotOkStatusException as e:
#     481       _ops.raise_from_not_ok_status(e, name)
# --> 482     except _core._FallbackException:
#     483       pass
#     484     try:
#     485       return add_v2_eager_fallback(
#
# KeyboardInterrupt:

# %% [markdown]
# ### L = 10

# %%
r_std_list_temp = []
a_std_list_temp = []

for i in tqdm(range(10)):
    models = pkl.load(open(f'../fitting_maps_bootstrap/models/integrable_model_L=10_bootstrap_seed{seed + i}.model', 'rb'))
    csr = model_to_csr(models)
    _, r_std, _, a_std = scatterplot_bootstrap(csr)
    r_std_list_temp.append(r_std)
    a_std_list_temp.append(a_std)


r_std_list_temp = np.array(r_std_list_temp)
a_std_list_temp = np.array(a_std_list_temp)

r_std = np.sqrt(np.mean(r_std_list_temp**2))/np.sqrt(10)
r_std_list.append(r_std)

a_std = np.sqrt(np.mean(a_std_list_temp**2))/np.sqrt(10)
a_std_list.append(a_std)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]

# %% [markdown]
# ### L = 20

# %%
r_std_list_temp = []
a_std_list_temp = []

for i in tqdm(range(10)):
    models = pkl.load(open(f'../fitting_maps_bootstrap/models/integrable_model_L=20_bootstrap_seed{seed + i}.model', 'rb'))
    csr = model_to_csr(models)
    _, r_std, _, a_std = scatterplot_bootstrap(csr)
    r_std_list_temp.append(r_std)
    a_std_list_temp.append(a_std)


r_std_list_temp = np.array(r_std_list_temp)
a_std_list_temp = np.array(a_std_list_temp)

r_std = np.sqrt(np.mean(r_std_list_temp**2))/np.sqrt(10)
r_std_list.append(r_std)

a_std = np.sqrt(np.mean(a_std_list_temp**2))/np.sqrt(10)
a_std_list.append(a_std)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]

# %% [markdown]
# ### L = 30

# %%
r_std_list_temp = []
a_std_list_temp = []

for i in tqdm(range(10)):
    models = pkl.load(open(f'../fitting_maps_bootstrap/models/integrable_model_L=30_bootstrap_seed{seed + i}.model', 'rb'))
    csr = model_to_csr(models)
    _, r_std, _, a_std = scatterplot_bootstrap(csr)
    r_std_list_temp.append(r_std)
    a_std_list_temp.append(a_std)


r_std_list_temp = np.array(r_std_list_temp)
a_std_list_temp = np.array(a_std_list_temp)

r_std = np.sqrt(np.mean(r_std_list_temp**2))/np.sqrt(10)
r_std_list.append(r_std)

a_std = np.sqrt(np.mean(a_std_list_temp**2))/np.sqrt(10)
a_std_list.append(a_std)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]

# %% [markdown]
# ### L = 40

# %%
r_std_list_temp = []
a_std_list_temp = []

for i in tqdm(range(10)):
    models = pkl.load(open(f'../fitting_maps_bootstrap/models/integrable_model_L=40_bootstrap_seed{seed + i}.model', 'rb'))
    csr = model_to_csr(models)
    _, r_std, _, a_std = scatterplot_bootstrap(csr)
    r_std_list_temp.append(r_std)
    a_std_list_temp.append(a_std)


r_std_list_temp = np.array(r_std_list_temp)
a_std_list_temp = np.array(a_std_list_temp)

r_std = np.sqrt(np.mean(r_std_list_temp**2))/np.sqrt(10)
r_std_list.append(r_std)

a_std = np.sqrt(np.mean(a_std_list_temp**2))/np.sqrt(10)
a_std_list.append(a_std)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]

# %% [markdown]
# ### L = 50

# %%
r_std_list_temp = []
a_std_list_temp = []

for i in tqdm(range(10)):
    models = pkl.load(open(f'../fitting_maps_bootstrap/models/integrable_model_L=50_bootstrap_seed{seed + i}.model', 'rb'))
    csr = model_to_csr(models)
    _, r_std, _, a_std = scatterplot_bootstrap(csr)
    r_std_list_temp.append(r_std)
    a_std_list_temp.append(a_std)


r_std_list_temp = np.array(r_std_list_temp)
a_std_list_temp = np.array(a_std_list_temp)

r_std = np.sqrt(np.mean(r_std_list_temp**2))/np.sqrt(10)
r_std_list.append(r_std)

a_std = np.sqrt(np.mean(a_std_list_temp**2))/np.sqrt(10)
a_std_list.append(a_std)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]

# %%
print(r_std,  a_std)
# Out:
# 0.006277596117212453 0.016024958872866684

# %%
np.savetxt('bookkeeping/figure3/scatterplot_std.txt', np.array([r_std_list, a_std_list]).T, delimiter=' ')
