# %% [markdown]
# # Marginals, Plotting

# %%
import sys
sys.path.insert(0, '../../src/')

import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf


#np.set_printoptions(threshold=sys.maxsize)
np.set_printoptions(precision=4)

import os
os.environ["CUDA_VISIBLE_DEVICES"] = "-1"
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)
# Out:
# 2025-12-11 11:09:58.532500: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-12-11 11:09:58.532785: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-12-11 11:09:58.574415: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %% [markdown]
# ## Radial, L = 5

# %%
[num_bins, FF_hist] = np.loadtxt('bookkeeping/figure3/radial_FF_theory.txt').T
[_, AI_hist] = np.loadtxt('bookkeeping/figure3/radial_AI_theory.txt').T
[exp_bins, exp_hist] = np.loadtxt("bookkeeping/figure3/radial_L=5.txt").T
bootstrap_err = np.loadtxt('bookkeeping/figure3/radial_std_L=5.txt')
fig = plt.figure()
ax = fig.add_subplot(111)

ax.plot(num_bins, FF_hist, 'b-', 
        label='Theoretic, Integrable',
        )

ax.plot(num_bins, AI_hist, 'g-', 
         label='Theoretic, Non-Integrable',
         )

#ax.fill_between(exp_bins, (exp_hist-bootstrap_err), (exp_hist+bootstrap_err), alpha=0.25, color="coral" )
ax.plot(exp_bins, exp_hist, 'o-', label='Experimental, T = 5', color="coral")


plt.xlim(0, 1)
plt.ylim(-0.1, 3.)
plt.xlabel(r'Radius ($r$)')
plt.ylabel(r'$P(r)$')
#ax.grid(True)
#ax.set_yticklabels([])
plt.legend()
plt.savefig("figures/transition_radial_L=5.svg", bbox_inches='tight')

plt.show()

# %% [markdown]
# ## Radial, L = 20

# %%
[num_bins, FF_hist] = np.loadtxt('bookkeeping/figure3/radial_FF_theory.txt').T
[_, AI_hist] = np.loadtxt('bookkeeping/figure3/radial_AI_theory.txt').T
[exp_bins, exp_hist,] = np.loadtxt("bookkeeping/figure3/radial_L=20.txt").T
bootstrap_err = np.loadtxt('bookkeeping/figure3/radial_std_L=20.txt')

fig = plt.figure()
ax = fig.add_subplot(111)

ax.plot(num_bins, FF_hist, 'b-', 
        #label='Theoretic, Integrable',
        )

ax.plot(num_bins, AI_hist, 'g-', 
#         label='Theoretic, Non-Integrable',
         )

#ax.fill_between(exp_bins, (exp_hist-bootstrap_err), (exp_hist+bootstrap_err), alpha=0.25, color="coral" )
ax.plot(exp_bins, exp_hist, 'o-', label='Experimental, T = 20', color="coral")


plt.xlim(0, 1)
plt.ylim(-0.1, 3.)
plt.xlabel(r'Radius ($r$)')
#plt.ylabel(r'$P(r)$')
#ax.grid(True)
#ax.set_yticklabels([])
plt.legend()
plt.savefig("figures/transition_radial_L=20.svg", bbox_inches='tight')

plt.show()

# %% [markdown]
# ## Radial, L = 50

# %%
[num_bins, FF_hist] = np.loadtxt('bookkeeping/figure3/radial_FF_theory.txt').T
[_, AI_hist] = np.loadtxt('bookkeeping/figure3/radial_AI_theory.txt').T
[exp_bins, exp_hist] = np.loadtxt("bookkeeping/figure3/radial_L=50.txt").T
bootstrap_err = np.loadtxt('bookkeeping/figure3/radial_std_L=50.txt')

fig = plt.figure()
ax = fig.add_subplot(111)

ax.plot(num_bins, FF_hist, 'b-', 
#        label='Theoretic, Integrable',
        )

ax.plot(num_bins, AI_hist, 'g-', 
#         label='Theoretic, Non-Integrable',
         )

#ax.fill_between(exp_bins, (exp_hist-bootstrap_err), (exp_hist+bootstrap_err), alpha=0.25, color="coral" )
ax.plot(exp_bins, exp_hist, 'o-', label='Experimental, T = 50', color="coral")


plt.xlim(0, 1)
plt.ylim(-0.1, 3.)
plt.xlabel(r'Radius ($r$)')
#plt.ylabel(r'$P(r)$')
#ax.grid(True)
#ax.set_yticklabels([])
plt.legend()
plt.savefig("figures/transition_radial_L=50.svg", bbox_inches='tight')

plt.show()

# %% [markdown]
# ## Angular, L = 5

# %%
[num_bins, FF_hist] = np.loadtxt('bookkeeping/figure3/angular_FF_theory.txt').T
[_, AI_hist] = np.loadtxt('bookkeeping/figure3/angular_AI_theory.txt').T

[exp_bins, exp_hist] = np.loadtxt("bookkeeping/figure3/angular_L=5.txt").T
bootstrap_err = np.loadtxt('bookkeeping/figure3/angular_std_L=5.txt')

plt.rc('font', size=16) 

fig = plt.figure()
ax = fig.add_subplot(111)

ax.plot(num_bins, FF_hist, 'b-', 
#        label='Theoretic, Integrable',
        )

ax.plot(num_bins, AI_hist, 'g-', 
#         label='Theoretic, Non-Integrable',
         )

#ax.fill_between(exp_bins, (exp_hist-bootstrap_err), (exp_hist+bootstrap_err), alpha=0.25, color="coral" )
ax.plot(exp_bins, exp_hist, 'o-', label='Experimental, T = 5', color="coral")


plt.xlim(-np.pi, np.pi)
plt.ylim(0.03, 0.36)
plt.xlabel(r'Angle ($\theta$)')
plt.ylabel(r'$P(\theta)$')
plt.legend()
plt.savefig("figures/transition_angular_L=5.svg", bbox_inches='tight')

plt.show()

# %% [markdown]
# ## Angular, L = 20

# %%
[num_bins, FF_hist] = np.loadtxt('bookkeeping/figure3/angular_FF_theory.txt').T
[_, AI_hist] = np.loadtxt('bookkeeping/figure3/angular_AI_theory.txt').T
[exp_bins, exp_hist] = np.loadtxt("bookkeeping/figure3/angular_L=20.txt").T
bootstrap_err = np.loadtxt('bookkeeping/figure3/angular_std_L=20.txt')

plt.rc('font', size=16) 
fig = plt.figure()
ax = fig.add_subplot(111)

ax.plot(num_bins, FF_hist, 'b-', 
#        label='Theoretic, Integrable',
        )

ax.plot(num_bins, AI_hist, 'g-', 
#         label='Theoretic, Non-Integrable',
         )

#ax.fill_between(exp_bins, (exp_hist-bootstrap_err), (exp_hist+bootstrap_err), alpha=0.25, color="coral" )
ax.plot(exp_bins, exp_hist, 'o-', label='Experimental, T = 20', color="coral")


plt.xlim(-np.pi, np.pi)
plt.ylim(0.03, 0.36)
plt.xlabel(r'Angle ($\theta$)')
#plt.ylabel(r'$P(\theta)$')
plt.legend()
plt.savefig("figures/transition_angular_L=20.svg", bbox_inches='tight')

plt.show()

# %% [markdown]
# ## Angular, L = 50

# %%
[num_bins, FF_hist] = np.loadtxt('bookkeeping/figure3/angular_FF_theory.txt').T
[_, AI_hist] = np.loadtxt('bookkeeping/figure3/angular_AI_theory.txt').T
[exp_bins, exp_hist] = np.loadtxt("bookkeeping/figure3/angular_L=50.txt").T
bootstrap_err = np.loadtxt('bookkeeping/figure3/angular_std_L=20.txt')

fig = plt.figure()
ax = fig.add_subplot(111)

ax.plot(num_bins, FF_hist, 'b-', 
#        label='Theoretic, Integrable',
        )

ax.plot(num_bins, AI_hist, 'g-', 
#         label='Theoretic, Non-Integrable',
         )

#ax.fill_between(exp_bins, (exp_hist-bootstrap_err), (exp_hist+bootstrap_err), alpha=0.25, color="coral" )
ax.plot(exp_bins, exp_hist, 'o-', label='Experimental, T = 50', color="coral")


plt.xlim(-np.pi, np.pi)
plt.ylim(0.03, 0.36)
plt.xlabel(r'Angle ($\theta$)')
#plt.ylabel(r'$P(\theta)$')
plt.legend()
plt.savefig("figures/transition_angular_L=50.svg", bbox_inches='tight')

plt.show()
